# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
orders = pd.read_csv('../data/Orders.csv')
returns = pd.read_csv('../data/Returns.csv')

# %%
pd.set_option('display.max_columns', 24)

# %%
orders.sample(5)
# Out:
#        Row.ID                 Order.ID Order.Date Ship.Date       Ship.Mode  \
# 25004   26950  IN-2013-ZD2192511-41615    12/7/13  12/14/13  Standard Class
# 46539   22018  ID-2015-NP1867059-42307   10/30/15   11/3/15  Standard Class
# 41865    4777  US-2015-HA1490598-42291   10/14/15  10/19/15  Standard Class
# 15128   42413   LI-2012-NG835573-41262   12/19/12  12/20/12        Same Day
# 26538   46046  UP-2014-CM1935137-41723    3/25/14   3/29/14  Standard Class
#
#       Customer.ID       Customer.Name    Segment  Postal.Code           City  \
# 25004  ZD-2192511  Zuschuss Donatelli   Consumer          NaN          Dhaka
# 46539  NP-1867059          Nora Paige   Consumer          NaN        Bandung
# 41865  HA-1490598       Helen Abelman   Consumer          NaN  San Miguelito
# 15128   NG-835573          Nat Gilpin  Corporate          NaN       Monrovia
# 26538  CM-1935137       Carlos Meador   Consumer          NaN       Zhytomyr
#
#              State     Country             Region        Market   Product.ID  \
# 25004        Dhaka  Bangladesh      Southern Asia  Asia Pacific  OFF-PA-4000
# 46539   Jawa Barat   Indonesia  Southeastern Asia  Asia Pacific  OFF-LA-4540
# 41865       Panama      Panama    Central America         LATAM  OFF-LA-4542
# 15128  Montserrado     Liberia     Western Africa        Africa  OFF-AR-6125
# 26538     Zhytomyr     Ukraine     Eastern Europe        Europe  OFF-LA-4539
#
#               Category Sub.Category  \
# 25004  Office Supplies        Paper
# 46539  Office Supplies       Labels
# 41865  Office Supplies       Labels
# 15128  Office Supplies          Art
# 26538  Office Supplies       Labels
#
#                                             Product.Name    Sales  Quantity  \
# 25004                       Eaton Message Books, Premium  $102.90         5
# 46539  Harbour Creations Legal Exhibit Labels, Laser ...   $29.02         5
# 41865     Harbour Creations Removable Labels, Adjustable   $25.78         6
# 15128                           Stanley Sketch Pad, Blue   $88.86         2
# 26538  Harbour Creations Legal Exhibit Labels, Alphab...  $107.70        10
#
#        Discount  Profit  Shipping.Cost Order.Priority
# 25004      0.00  $49.35          8.220            Low
# 46539      0.47  -$9.98          1.530         Medium
# 41865      0.40  -$9.02          1.966           High
# 15128      0.00  $29.28         19.480           High
# 26538      0.00  $46.20          7.260         Medium

# %%
returns.sample(5)
# Out:
#      Returned                  Order ID           Region
# 605       Yes  IT-2013-GT14710125-41392   Western Europe
# 178       Yes   IN-2014-DJ1342058-41646    Southern Asia
# 661       Yes   ES-2012-JK1564048-41191   Western Europe
# 593       Yes   ES-2013-CS1225048-41579   Western Europe
# 1012      Yes   MX-2012-RE1940539-41195  Central America

# %%
orders['Sales'] = [x.replace('$', '') for x in orders['Sales']]
orders['Sales'] = [x.replace(',', '') for x in orders['Sales']]
orders['Sales'].dtype
# Out:
# dtype('O')

# %%
orders['Sales'] = orders['Sales'].astype(float)
orders['Sales'].dtype
# Out:
# dtype('float64')

# %%
orders['Profit'] = [x.replace('$', '') for x in orders['Profit']]
orders['Profit'] = [x.replace(',', '') for x in orders['Profit']]

# %%
orders['Profit'] = orders['Profit'].astype(float)

# %%
orders['Profit'].dtype
# Out:
# dtype('float64')

# %%
orders.sample(10)
# Out:
#        Row.ID                  Order.ID Order.Date Ship.Date       Ship.Mode  \
# 22669   18743  ES-2012-KN16705120-41257   12/14/12  12/18/12  Standard Class
# 35091    9517   US-2014-EA1403536-41919    10/7/14   10/9/14    Second Class
# 21745   31052   IN-2014-PF1922592-41982    12/9/14  12/15/14  Standard Class
# 39882   16738   ES-2015-BS1175564-42026    1/22/15   1/26/15  Standard Class
# 33127   24727   IN-2013-GB1457558-41605   11/27/13   12/3/13  Standard Class
# 24975   21461    ID-2015-HG148457-42357   12/19/15  12/26/15  Standard Class
# 2648     1971   MX-2012-RA1991518-40912     1/4/12    1/9/12    Second Class
# 43504   19677  IT-2014-HD14785124-41878    8/27/14   8/31/14  Standard Class
# 30517   51252    IZ-2013-PB915061-41564   10/17/13  10/21/13  Standard Class
# 800     28516    ID-2015-ST205307-42336   11/28/15   12/5/15  Standard Class
#
#        Customer.ID      Customer.Name      Segment  Postal.Code  \
# 22669  KN-16705120      Kristina Nunn  Home Office          NaN
# 35091   EA-1403536      Erin Ashbrook    Corporate          NaN
# 21745   PF-1922592  Phillip Flathmann     Consumer          NaN
# 39882   BS-1175564      Bruce Stewart     Consumer          NaN
# 33127   GB-1457558  Giulietta Baptist     Consumer          NaN
# 24975    HG-148457       Harry Greene     Consumer          NaN
# 2648    RA-1991518  Russell Applegate     Consumer          NaN
# 43504  HD-14785124      Harold Dahlen  Home Office          NaN
# 30517    PB-915061       Philip Brown     Consumer          NaN
# 800      ST-205307           Shui Tom     Consumer          NaN
#
#                       City          State             Country  \
# 22669             Alicante     Valenciana               Spain
# 35091        Santo Domingo  Santo Domingo  Dominican Republic
# 21745           Upper Hutt     Wellington         New Zealand
# 39882  Falconara Marittima         Marche               Italy
# 33127             Bilaspur  Uttar Pradesh               India
# 24975            Caloundra     Queensland           Australia
# 2648     Francisco Beltrão         Parana              Brazil
# 43504            Stockholm      Stockholm              Sweden
# 30517                Basra      Al Basrah                Iraq
# 800              Bundaberg     Queensland           Australia
#
#                 Region        Market   Product.ID         Category  \
# 22669  Southern Europe        Europe  OFF-ST-5695  Office Supplies
# 35091        Caribbean         LATAM  OFF-SU-4988  Office Supplies
# 21745          Oceania  Asia Pacific  OFF-AR-3471  Office Supplies
# 39882  Southern Europe        Europe  OFF-AR-5923  Office Supplies
# 33127    Southern Asia  Asia Pacific  OFF-FA-3063  Office Supplies
# 24975          Oceania  Asia Pacific  OFF-EN-4443  Office Supplies
# 2648     South America         LATAM  FUR-BO-3891        Furniture
# 43504  Northern Europe        Europe  OFF-EN-4919  Office Supplies
# 30517     Western Asia  Asia Pacific  TEC-CO-6005       Technology
# 800            Oceania  Asia Pacific  FUR-TA-3766        Furniture
#
#       Sub.Category                                      Product.Name    Sales  \
# 22669      Storage                        Rogers Folders, Industrial   168.32
# 35091     Supplies                          Kleencut Scissors, Steel    11.57
# 21745          Art                       BIC Sketch Pad, Water Color   103.68
# 39882          Art             Sanford Pencil Sharpener, Water Color    26.10
# 33127    Fasteners                      Advantus Rubber Bands, Metal    66.84
# 24975    Envelopes                       GlobeWeis Mailers, Recycled   134.46
# 2648     Bookcases                      Dania Classic Bookcase, Pine  1648.44
# 43504    Envelopes              Jiffy Manila Envelope, Security-Tint    14.21
# 30517      Copiers                      Sharp Personal Copier, Color   121.44
# 800         Tables  Chromcraft Conference Table, with Bottom Storage  1832.61
#
#        Quantity  Discount  Profit  Shipping.Cost Order.Priority
# 22669         6       0.1    7.40          9.960         Medium
# 35091         1       0.2    2.45          3.554       Critical
# 21745         2       0.0   47.64         10.790         Medium
# 39882         1       0.0    6.78          2.270           High
# 33127         4       0.0   21.96          4.220         Medium
# 24975         4       0.1   52.26          8.230         Medium
# 2648          6       0.0  609.84        109.129         Medium
# 43504         1       0.5   -0.29          1.810         Medium
# 30517         1       0.0   32.76          5.270         Medium
# 800           3       0.3 -445.11        228.890            Low

# %%
orders.columns
# Out:
# Index(['Row.ID', 'Order.ID', 'Order.Date', 'Ship.Date', 'Ship.Mode',
#        'Customer.ID', 'Customer.Name', 'Segment', 'Postal.Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product.ID', 'Category',
#        'Sub.Category', 'Product.Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping.Cost', 'Order.Priority'],
#       dtype='object')

# %%
orders['Order.Date'] = pd.to_datetime(orders['Order.Date'])

# %%
orders['Order.Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
orders['Ship.Date'] = pd.to_datetime(orders['Ship.Date'])

# %%
orders['Month'] = [x.month for x in orders['Order.Date']]
orders.sample(5)
# Out:
#        Row.ID                  Order.ID Order.Date  Ship.Date       Ship.Mode  \
# 21880   23921   IN-2015-RD1981027-42181 2015-06-26 2015-06-28    Second Class
# 36177   14582   IT-2013-ST2053064-41607 2013-11-29 2013-12-01    Second Class
# 1107    29617   IN-2015-SP2065059-42290 2015-10-13 2015-10-18  Standard Class
# 6466    27481   IN-2014-MH1729058-41956 2014-11-13 2014-11-15    Second Class
# 37070   41240  CA-2012-MD17350140-41270 2012-12-27 2013-01-02  Standard Class
#
#         Customer.ID     Customer.Name      Segment  Postal.Code         City  \
# 21880    RD-1981027  Ross DeVincentis  Home Office          NaN    Changchun
# 36177    ST-2053064          Shui Tom     Consumer          NaN        Milan
# 1107     SP-2065059  Stephanie Phelps    Corporate          NaN   Balikpapan
# 6466     MH-1729058     Marc Harrigan  Home Office          NaN  Tirunelveli
# 37070  MD-173501404     Maribeth Dona     Consumer      92804.0      Anaheim
#
#                   State        Country  ...         Market   Product.ID  \
# 21880             Jilin          China  ...   Asia Pacific  OFF-FA-6189
# 36177          Lombardy          Italy  ...         Europe  FUR-CH-4520
# 1107   Kalimantan Timur      Indonesia  ...   Asia Pacific  OFF-ST-4079
# 6466         Tamil Nadu          India  ...   Asia Pacific  FUR-TA-3341
# 37070        California  United States  ...           USCA  OFF-SU-2964
#
#               Category Sub.Category                              Product.Name  \
# 21880  Office Supplies    Fasteners     Stockwell Paper Clips, Assorted Sizes
# 36177        Furniture       Chairs         Harbour Creations Bag Chairs, Red
# 1107   Office Supplies      Storage                 Eldon Lockers, Industrial
# 6466         Furniture       Tables  Barricks Computer Table, Fully Assembled
# 37070  Office Supplies     Supplies                  Acme Box Cutter Scissors
#
#          Sales  Quantity  Discount  Profit  Shipping.Cost  Order.Priority  \
# 21880    94.50         7      0.00    9.45          10.67          Medium
# 36177    73.94         3      0.60  -31.45           3.24          Medium
# 1107   1317.31         8      0.17  396.67         191.58            High
# 6466    477.84         1      0.00   14.31          52.69          Medium
# 37070    51.15         5      0.00   13.30           2.23          Medium
#
#       Month
# 21880     6
# 36177    11
# 1107     10
# 6466     11
# 37070    12
#
# [5 rows x 25 columns]

# %%
by_cat = orders.groupby(['Month', 'Category']).agg({'Quantity':sum}).reset_index()


furn = by_cat[by_cat['Category'] == 'Furniture']
ofc = by_cat[by_cat['Category'] == 'Office Supplies']
tech = by_cat[by_cat['Category'] == 'Technology']

cats = [furn, ofc, tech]

for i in cats:
    i.plot.bar(x='Month', y='Quantity')

# %%
#losses = orders.loc[orders['Profit'] < 0]
#sum(round(losses['Profit'], 2))

returns.columns = ['Returned', 'Order.ID', 'Region']

# %%
returns = returns.merge(orders, how='left', on='Order.ID')

# %%
returns.sample(5)
# Out:
#      Returned                  Order.ID         Region_x  Row.ID Order.Date  \
# 1429      Yes   PL-2013-JF5190103-41443   Eastern Europe   42088 2013-06-18
# 1982      Yes  CA-2015-EB13705140-42321       Eastern US   31802 2015-11-13
# 691       Yes   MX-2014-DC1328518-41751    South America    4196 2014-04-22
# 525       Yes   MX-2015-DV1304593-42215  Central America    5329 2015-07-30
# 1518      Yes    IN-2014-TS211607-41875          Oceania   31030 2014-08-24
#
#       Ship.Date       Ship.Mode   Customer.ID    Customer.Name    Segment  \
# 1429 2013-06-23  Standard Class    JF-5190103     Jamie Frazer   Consumer
# 1982 2015-11-16    Second Class  EB-137051406       Ed Braxton  Corporate
# 691  2014-04-26  Standard Class    DC-1328518     Debra Catini   Consumer
# 525  2015-08-03  Standard Class    DV-1304593  Darrin Van Huff  Corporate
# 1518 2014-08-28  Standard Class     TS-211607    Theresa Swint  Corporate
#
#       Postal.Code                 City  ...          Market   Product.ID  \
# 1429          NaN               Warsaw  ...          Europe  FUR-CH-4626
# 1982      10024.0        New York City  ...            USCA  OFF-BI-3269
# 691           NaN  Presidente Prudente  ...           LATAM  OFF-PA-5869
# 525           NaN              Managua  ...           LATAM  FUR-BO-3887
# 1518          NaN           Queanbeyan  ...    Asia Pacific  OFF-PA-4176
#
#              Category Sub.Category  \
# 1429        Furniture       Chairs
# 1982  Office Supplies      Binders
# 691   Office Supplies        Paper
# 525         Furniture    Bookcases
# 1518  Office Supplies        Paper
#
#                                      Product.Name   Sales Quantity Discount  \
# 1429                   Hon Bag Chairs, Adjustable   47.64        1      0.0
# 1982  Avery Durable Slant Ring Binders, No Labels   15.92        5      0.2
# 691                SanDisk Memo Slips, Multicolor   36.78        3      0.0
# 525                   Dania 3-Shelf Cabinet, Pine  761.60        8      0.0
# 1518               Enermax Note Cards, Multicolor  130.56        4      0.0
#
#       Profit  Shipping.Cost  Order.Priority  Month
# 1429   10.47          2.640          Medium      6
# 1982    5.37          3.080            High     11
# 691     7.32          1.163          Medium      4
# 525   114.24         71.153            High      7
# 1518    7.80         10.860          Medium      8
#
# [5 rows x 27 columns]

# %%
returns['Year'] = [x.year for x in returns['Order.Date']]

# %%
#returns.groupby('Year').agg({'Profit': sum})

neg_profit = returns.loc[returns['Profit'] < 0]
neg_profit.groupby('Year').agg({'Profit': sum})
# Out:
#         Profit
# Year
# 2012  -5772.54
# 2013  -7713.03
# 2014  -7439.43
# 2015 -15907.60

# %%
repeat_ret = returns.groupby('Customer.ID').agg({'Quantity': sum}).sort_values(by = 'Quantity', ascending=False)

more_than_one = len(repeat_ret.loc[repeat_ret['Quantity'] > 1])

more_than_five = len(repeat_ret.loc[repeat_ret['Quantity'] > 5])

repeat_ret
# Out:
#               Quantity
# Customer.ID
# PO-1885082          51
# KH-165101404        46
# SS-2059059          37
# TB-2140066          36
# AJ-1096031          35
# JP-1552045          33
# MY-1829582          32
# SS-205151408        32
# SC-202301404        32
# BP-110951404        30
# GK-14620101         29
# JK-1609027          29
# KH-166301408        29
# MR-1754564          29
# BM-1114055          28
# ES-1408018          27
# GT-147101404        27
# SC-2080059          27
# NC-185351404        27
# BB-1154548          27
# PO-1885048          26
# DH-130751404        26
# MG-181451404        26
# BT-1139564          26
# SG-200801404        26
# PB-19210127         25
# AT-1073545          24
# DB-13555139         24
# JP-155205           24
# DL-129257           24
# ...                ...
# CM-21603             1
# HG-148451406         1
# DA-1345058           1
# GR-1456054           1
# GM-4680110           1
# PF-192251408         1
# CS-186038            1
# CG-204095            1
# LS-172007            1
# IM-1507058           1
# JD-6015134           1
# JK-1609048           1
# SS-1051560           1
# SC-1068022           1
# BM-1785129           1
# BP-105095            1
# LA-678086            1
# LL-6840103           1
# DL-2925137           1
# JC-577594            1
# NF-838538            1
# FH-4365134           1
# MN-7935147           1
# FH-436560            1
# SB-1018538           1
# DK-130901402         1
# SA-10830107          1
# MC-1759039           1
# DJ-1363018           1
# EB-411095            1
#
# [1061 rows x 1 columns]

# %%
returns.groupby('Region_x').agg({'Quantity': sum}).sort_values(by = 'Quantity', ascending=False)
# Out:
#                    Quantity
# Region_x
# Western Europe          940
# Central America         885
# Western US              674
# Oceania                 565
# Southeastern Asia       508
# Eastern US              487
# Eastern Asia            472
# South America           465
# Southern Europe         423
# Southern US             346
# Southern Asia           328
# Central US              289
# Northern Europe         272
# Western Asia            263
# Caribbean               253
# North Africa            113
# Western Africa          111
# Eastern Europe           91
# Southern Africa          62
# Eastern Africa           37
# Central Africa           33
# Eastern Canada           27
# Central Asia             25
# Western Canada            6

# %%
returns.groupby('Category').agg({'Quantity': sum}).sort_values(by = 'Quantity', ascending=False)
# Out:
#                  Quantity
# Category
# Office Supplies      4605
# Technology           1556
# Furniture            1514

# %%
returns.groupby('Sub.Category').agg({'Quantity': sum}).sort_values(by = 'Quantity', ascending=False)
# Out:
#               Quantity
# Sub.Category
# Binders            912
# Art                749
# Storage            702
# Paper              528
# Phones             523
# Chairs             506
# Accessories        503
# Furnishings        497
# Labels             480
# Bookcases          361
# Supplies           351
# Fasteners          347
# Envelopes          336
# Copiers            310
# Machines           220
# Appliances         200
# Tables             150

# %% [markdown]
# #  Part 2

# %%
returns_bool = returns[['Returned', 'Order.ID']]
returns_bool
# Out:
#      Returned                  Order.ID
# 0         Yes  CA-2012-SA20830140-41210
# 1         Yes  IN-2012-PB19210127-41259
# 2         Yes  IN-2012-PB19210127-41259
# 3         Yes  IN-2012-PB19210127-41259
# 4         Yes  IN-2012-PB19210127-41259
# 5         Yes  IN-2012-PB19210127-41259
# 6         Yes  IN-2012-PB19210127-41259
# 7         Yes  IN-2012-PB19210127-41259
# 8         Yes  IN-2012-PB19210127-41259
# 9         Yes  CA-2012-SC20095140-41174
# 10        Yes  CA-2012-SC20095140-41174
# 11        Yes  CA-2012-SC20095140-41174
# 12        Yes  CA-2012-SC20095140-41174
# 13        Yes    IN-2015-JH158207-42140
# 14        Yes    IN-2015-JH158207-42140
# 15        Yes    IN-2015-JH158207-42140
# 16        Yes    IN-2015-JH158207-42140
# 17        Yes    IN-2014-LC168857-41747
# 18        Yes   ID-2013-AB1001527-41439
# 19        Yes   ID-2013-AB1001527-41439
# 20        Yes   ES-2015-RA1994545-42218
# 21        Yes  CA-2014-TB21280140-41724
# 22        Yes  ES-2014-JF15295120-41924
# 23        Yes   IN-2014-NM1844527-41800
# 24        Yes   IN-2014-NM1844527-41800
# 25        Yes   IN-2014-NM1844527-41800
# 26        Yes    IN-2015-GB145307-42260
# 27        Yes    ES-2012-SC208458-41070
# 28        Yes  TU-2013-SF10200134-41417
# 29        Yes  TU-2013-SF10200134-41417
# ...       ...                       ...
# 2190      Yes  CA-2015-SC20575140-42236
# 2191      Yes  CA-2015-GK14620140-42257
# 2192      Yes   ZA-2015-MN7935147-42339
# 2193      Yes   ES-2012-AA1064564-41268
# 2194      Yes    IN-2015-MO178007-42363
# 2195      Yes  CA-2013-AI10855140-41628
# 2196      Yes  ES-2015-WB21850139-42248
# 2197      Yes     AG-2014-CM21603-41755
# 2198      Yes    IN-2012-RC198257-41167
# 2199      Yes    IN-2013-JM152657-41576
# 2200      Yes   TU-2012-PF9165134-41074
# 2201      Yes  US-2012-TH21235140-41216
# 2202      Yes   US-2013-PF1916582-41445
# 2203      Yes  CA-2015-AA10645140-42314
# 2204      Yes  ES-2012-MO17950120-41137
# 2205      Yes   ES-2013-PB1915034-41373
# 2206      Yes    NI-2014-CG204095-41856
# 2207      Yes    NI-2015-EB411095-42174
# 2208      Yes  IN-2014-KD16345144-41768
# 2209      Yes  IN-2015-LA16780102-42095
# 2210      Yes   IN-2014-SE2011066-41772
# 2211      Yes   ES-2015-AS1024064-42297
# 2212      Yes   ZA-2014-LS6945147-41672
# 2213      Yes  TU-2014-SF10965134-41992
# 2214      Yes  US-2014-LB16795140-41957
# 2215      Yes   IN-2014-DA1345058-41769
# 2216      Yes  US-2013-HG14845140-41530
# 2217      Yes   US-2013-SJ2021582-41543
# 2218      Yes  CA-2015-EB13870140-42269
# 2219      Yes    EG-2014-PM894038-41846
#
# [2220 rows x 2 columns]

# %%
orders = orders.merge(returns_bool, how='outer', on='Order.ID')

# %%
orders['Returned'] = [1 if x == 'Yes' else 0 for x in orders['Returned']]

# %%
orders['Process.Time'] = orders['Ship.Date'] - orders['Order.Date']

# %%
orders.sample(5)
# Out:
#        Row.ID                  Order.ID Order.Date  Ship.Date       Ship.Mode  \
# 28083   21526    ID-2013-TS212057-41426 2013-06-01 2013-06-06  Standard Class
# 55426   38428  CA-2015-TT21460140-42335 2015-11-27 2015-12-02  Standard Class
# 49939   38417  US-2012-MM18280140-40929 2012-01-21 2012-01-27  Standard Class
# 19200    2980   MX-2014-NC1862593-41955 2014-11-12 2014-11-14    Second Class
# 37479   41304    MO-2015-KW657086-42321 2015-11-13 2015-11-16     First Class
#
#         Customer.ID       Customer.Name      Segment  Postal.Code      City  \
# 28083     TS-212057         Thomas Seio    Corporate          NaN   Bendigo
# 55426  TT-214601402       Tonja Turnell  Home Office      47374.0  Richmond
# 49939  MM-182801408  Muhammed MacIntyre    Corporate      37167.0    Smyrna
# 19200    NC-1862593         Noah Childs    Corporate          NaN   Managua
# 37479     KW-657086      Kelly Williams     Consumer          NaN   Kenitra
#
#                           State        Country     ...              Category  \
# 28083                  Victoria      Australia     ...            Technology
# 55426                   Indiana  United States     ...             Furniture
# 49939                 Tennessee  United States     ...       Office Supplies
# 19200                   Managua      Nicaragua     ...       Office Supplies
# 37479  Gharb-Chrarda-Béni Hssen        Morocco     ...       Office Supplies
#
#       Sub.Category                               Product.Name   Sales  \
# 28083      Copiers                           Sharp Ink, Color  226.53
# 55426       Tables                 KI Adjustable-Height Table  257.94
# 49939      Binders  GBC DocuBind TL200 Manual Binding Machine   67.19
# 19200      Storage                    Smead Trays, Wire Frame  126.80
# 37479      Binders         Acco Hole Reinforcements, Recycled   14.04
#
#       Quantity Discount  Profit  Shipping.Cost  Order.Priority  Month  \
# 28083        2      0.1   -0.03         20.100          Medium      6
# 55426        3      0.0   67.06         21.240          Medium     11
# 49939        1      0.7  -51.52          3.000          Medium      1
# 19200        4      0.0   26.56         37.605        Critical     11
# 37479        2      0.0    7.02          2.040          Medium     11
#
#        Returned Process.Time
# 28083         0       5 days
# 55426         0       5 days
# 49939         0       6 days
# 19200         1       2 days
# 37479         0       3 days
#
# [5 rows x 27 columns]
